# %% [markdown]
# # Fitness Cofficient For This Case
# There are 2 conditions acceptable
# 1. Number of items included (I~n~)
# 2. Cost of wasteage from roll (C~n~)
# 3. Cost of Number of roll used (R~n~)
#
#
# Let's assume for now to find something with zero wasted.
# So C~n~ is zero.
#
# F~n~ = In

# %%
import random
items=[   # items dictionary
    {
    "id": "0",
    "L" : 5,
    "W" : 7,
    "N" : 2
    },
    {
    "id": "1",
    "L" : 7,
    "W" : 0,
    "N" : 1
    },
    {
    "id": "2",
    "L" : 3,
    "W" : 2,
    "N" : 3
    },
    {
    "id": "3",
    "L" : 6,
    "W" : 0,
    "N" : 4
    },
    {
    "id": "4",
    "L" : 8,
    "W" : 3,
    "N" : 2
    },
    {
    "id": "5",
    "L" : 9,
    "W" : 4,
    "N" : 5
    },
    {
    "id": "6",
    "L" : 7,
    "W" : 8,
    "N" : 3
    },
    {
        "id" : "7",
        "L" : 8,
        "W" : 9
    "N" : 2
    }
]

class state(object):
    
    def __init__(self):
        global items
        n=len(items)
        self.Rn=0
        self.values={}
        
        for i in items:
            coin_flip=random.randint(0,1)
            for j in range(random.randint(0,n)):
                if coin_flip==0:
                        self.values[(i["id"],"W")]=self.values.get(i["id"],[]).append(random.randint(0,i["W"]))
                else:
                        self.values[(i["id"],"L")]=self.values.get(i["id"],[]).append(random.randint(0,i["L"]))
    def fitness(self):
        global items
        for k in self.vlaues:
            for b
